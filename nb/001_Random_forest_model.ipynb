# %%
cd /content/drive/MyDrive/Kaggle/Child Institute/
# Out:
# /content/drive/MyDrive/Kaggle/Child Institute

# %% [markdown]
# # APIを使ったデータのダウンロード

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install kaggle

# %%
import os
import json
f = open("/content/drive/MyDrive/kaggle.json", 'r')
json_data = json.load(f)
os.environ['KAGGLE_USERNAME'] = json_data['username']
os.environ['KAGGLE_KEY'] = json_data['key']

# %%
# !kaggle competitions download -c child-mind-institute-detect-sleep-states
# Out:
# ...
#  99% 806M/811M [00:22<00:00, 42.6MB/s]
# 100% 811M/811M [00:22<00:00, 38.2MB/s]

# %%
# !unzip '/content/child-mind-institute-detect-sleep-states.zip'
# Out:
# Archive:  /content/child-mind-institute-detect-sleep-states.zip
#   inflating: sample_submission.csv
#   inflating: test_series.parquet
#   inflating: train_events.csv
#   inflating: train_series.parquet

# %% [markdown]
# # GitHub接続

# %%
# %cd /content/drive/MyDrive/Kaggle/Child Institute/
# !git clone https://github.com/cubenomuta/kaggle-Child-Mind-Institute.git
# Out:
# /content/drive/MyDrive/Kaggle/Child Institute
# fatal: destination path 'kaggle-Child-Mind-Institute' already exists and is not an empty directory.

# %%
# !git config --global user.email "037takunomu.ya@gmail.com"
# !git config --global user.name "cubenomuta"

# %%
# %cd kaggle-Child-Mind-Institute
# Out:
# /content/drive/MyDrive/Kaggle/Child Institute/kaggle-Child-Mind-Institute

# %%
# !cp ../001_Random_forest_model.ipynb ./

# %%
# !git add 001_Random_forest_model.ipynb

# %%
# !git commit -m "first commit"
# Out:
# [main bf828e7] first commit
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git log
# Out:
# commit bf828e7d89b1f8119993ca93177f053f463dc634 (HEAD -> main)
# Author: cubenomuta <037takunomu.ya@gmail.com>
# Date:   Sat Nov 11 04:08:19 2023 +0000
#
#     first commit
#
# commit 3aa05d4094bc2b704b3720cb13e538e94c1bb87c
# Author: cubenomuta <037takunomu.ya@gmail.com>
# Date:   Sat Nov 11 03:04:16 2023 +0000
#
#     first commit
#
# commit 60c8c471eee6f45f3bd2dc805bb0e72fef2c88a3
# Author: nonnta <125228706+cubenomuta@users.noreply.github.com>
# Date:   Thu Nov 9 13:06:20 2023 +0900
#
#     Update README.md
#
# commit 6816d666c98f07892ce7014381158378120c57c8
# Author: nonnta <125228706+cubenomuta@users.noreply.github.com>
# Date:   Thu Nov 9 13:05:16 2023 +0900
#
#     Update README.md
#
# commit 9a5cf4868f802c4a237bfd00d59bc4ce21214555
# Author: nonnta <125228706+cubenomuta@users.noreply.github.com>
# Date:   Thu Nov 9 13:03:52 2023 +0900
#
#     Update README.md
#
# commit 9366a6572147c068bacebb7a3e818687d1bc61be
# Author: nonnta <125228706+cubenomuta@users.noreply.github.com>
# ...

# %%
# !git remote -v

# %%
# !git remote set-url origin https://cubenomuta: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@github.com/cubenomuta/kaggle-Child-Mind-Institute.git
# Out:
# error: No such remote 'origin'

# %%
# !git pull origin main
# Out:
# From https://github.com/cubenomuta/kaggle-Child-Mind-Institute
#  * branch            main       -> FETCH_HEAD
# hint: You have divergent branches and need to specify how to reconcile them.
# hint: You can do so by running one of the following commands sometime before
# hint: your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# fatal: Need to specify how to reconcile divergent branches.

# %%
# !git push origin main
# Out:
# To https://github.com/cubenomuta/kaggle-Child-Mind-Institute.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/cubenomuta/kaggle-Child-Mind-Institute.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %% [markdown]
# # ここから実行

# %%
import sys
from pathlib  import Path

if 'google.colab' in sys.modules: #colab環境のファイルパス
  INPUT = ('/content/')
elif 'kaggle_web_client' in sys.modules: #kaggle環境のファイルパス
  INPUT = ('/kaggle/input/')
